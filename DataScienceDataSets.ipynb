# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Lenovo\Downloads\DataScience_salaries_2024.csv")
df
df1 = df

# %%
# Shuffle the dataset
shuffled_df = df1.sample(n=len(df1))
# Reset the index of the shuffled DataFrame
shuffled_df = shuffled_df.reset_index(drop=True)
shuffled_df
# Out:
#        work_year experience_level employment_type                  job_title  \
# 0           2023               SE              FT         Analytics Engineer
# 1           2024               SE              FT  Machine Learning Engineer
# 2           2023               MI              FT  Machine Learning Engineer
# 3           2023               SE              FT             Data Scientist
# 4           2023               SE              FT  Machine Learning Engineer
# ...          ...              ...             ...                        ...
# 14833       2024               MI              FT         Research Scientist
# 14834       2023               EN              FT               AI Developer
# 14835       2023               SE              FT               Data Manager
# 14836       2024               MI              FT             Data Scientist
# 14837       2023               SE              FT         Research Scientist
#
# ...

# %%
shuffled_df.head(15)
# Out:
#     work_year experience_level employment_type                  job_title  \
# 0        2023               SE              FT         Analytics Engineer
# 1        2024               SE              FT  Machine Learning Engineer
# 2        2023               MI              FT  Machine Learning Engineer
# 3        2023               SE              FT             Data Scientist
# 4        2023               SE              FT  Machine Learning Engineer
# 5        2022               SE              FT              Data Engineer
# 6        2024               MI              FT              Data Engineer
# 7        2023               MI              FT               Data Analyst
# 8        2023               SE              FT  Machine Learning Engineer
# 9        2023               SE              FT         Analytics Engineer
# 10       2023               SE              FT              Data Engineer
# 11       2024               SE              FT             Data Scientist
# ...
